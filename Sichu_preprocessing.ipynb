# %% [markdown]
# # 전처리

# %%
import re
import pickle
import pandas as pd

# %% [markdown]
# ## 소속 코드 전처리

# %%
with open('category_codes.pickle','rb') as f:
    category_codes = pickle.load(f)

codes = category_codes.values()

# %%
code_book=pd.DataFrame()
for cd in list(codes):
    temp = pd.DataFrame(cd).T
    code_book = pd.concat([code_book,temp])
code_book=code_book.reset_index()
code_book.columns=['code','name','upper']

# %%
def find_major(x):
    if x not in code_book['upper'].unique():
        return '전공'
    else :
        return '미정'

# %%
code_book['assign'] = code_book['code'].apply(find_major)
code_book.loc[code_book['upper']=='없음','assign']='단과대'

# %% [markdown]
# ## 강의정보 데이터 전처리

# %%
# DF 전처리 (과목별 GROUP)

df = pd.read_pickle('lecture_raw.csv')
df_sum = df.groupby(['과목명','교수명'])['과목분류'].unique().reset_index()

cols = list(df.columns[3:])

for c in cols:
    df_sum2 = df.groupby(['과목명','교수명'])[c].unique().reset_index()
    df_sum = pd.merge(df_sum,df_sum2)

# %%
# 학부,학과 단위로 Category 설정
college = list(code_book.query('assign=="단과대"')['code'])
df_sum['소속코드'] = df_sum['소속코드'].apply(lambda x:list(set(x)-set(college)))

# %%
# 최근값으로 대치, 결측값 '정보없음'으로 통일

df_sum['과목코드'] = df_sum['과목코드'].apply(lambda x:x[-1])
df_sum['평점'] = df_sum['평점'].apply(lambda x:x[-1])
df_sum['시간'] = df_sum['시간'].apply(lambda x:x[-1])
df_sum['학점'] = df_sum['학점'].apply(lambda x:x[-1])
df_sum['비고'] = df_sum['비고'].apply(lambda x:x[-1])
df_sum['링크'] = df_sum['링크'].apply(lambda x:x[-1])

df_sum['비고'].fillna('정보없음',inplace=True)
df_sum['시간'].fillna('정보없음',inplace=True)

# %%
# 소속코드 -> 소속이름 으로 대치
def get_college(code):
    string = code_book.query('code==@code')['name'].values
    return string

# %%
df_sum['소속코드'] = df_sum['소속코드'].apply(lambda x: ((get_college(x))[-1]))

# %%
df_sum.to_pickle('lecture_processed.pickle')

# %% [markdown]
# ## 이모지 코드 생성

# %%
def get_emoji(name):
    e = ""
    if re.search('문학',name) != None:
        e = '<i class="fas fa-pen-nib"></i>'
    elif re.search('건축',name) != None:
        e = '<i class="fas fa-drafting-compass"></i>'
    elif re.search('경제',name) != None :
        e = '<i class="fas fa-coins"></i>'
    elif re.search('디자인|미술|공예',name) != None :
        e = '<i class="fas fa-palette"></i>'
    elif re.search('경영',name) != None :
        e = '<i class="fas fa-user-tie"></i>'
    elif re.search('법|사회|교육',name) != None :
        e = '<i class="fas fa-balance-scale"></i>'
    elif re.search('공학|나노|전자|물리|화학|수학',name) != None:
        e = '<i class="fas fa-wrench"></i>'
    elif re.search('행정',name) != None:
        e = '<i class="fas fa-book-open"></i>'
    elif re.search('체육|스포츠',name) != None:
        e = '<i class="fas fa-swimmer"></i>'
    elif re.search('소프트',name) != None:
        e = '<i class="fas fa-code"></i>'
    elif re.search('KMU|국제|정치|유라시아|일본|중국',name) != None:
        e = '<i class="fas fa-globe-americas"></i>'
    elif re.search('사학',name) != None:
        e = '<i class="fas fa-scroll-old"></i>'
    elif re.search('언론|정치',name) != None:
        e = '<i class="fas fa-newspaper"></i>'
    elif re.search('공연',name) != None:
        e = '<i class="fas fa-theater-masks"></i>'
    elif re.search('자동차',name) != None:
        e = '<i class="fas fa-car-side"></i>'
    elif re.search('회계',name) != None:
        e = '<i class="fas fa-file-invoice-dollar"></i>'
    elif re.search('음악',name) != None :
        e = '<i class="fas fa-music"></i>'
    elif re.search('발효|바이오|산림|식품',name) != None:
        e = '<i class="fas fa-biohazard"></i>'
    else :
        e = '<i class="fas fa-university"></i>'
    
    
    return e

# %%
emoji = pd.DataFrame(df_sum['소속코드'].unique(),columns=['name'])
emoji['url'] = emoji['name'].apply(get_emoji)

emoji_export={}
for n,u in zip(emoji['name'],emoji['url']):
    emoji_export[n]=u

# %%
import json
with open('emoji.json', 'w', encoding = 'utf-8') as f:
    json.dump(emoji_export, f , ensure_ascii=False)

# %% [markdown]
# # 데이터 가져오기

# %%
import pandas as pd
import json
import pickle

# %%
lec_sim = pd.read_pickle('lec_sim.pkl')
prof_sim = pd.read_pickle('prof_sim.pkl')
df_sum = pd.read_pickle('lecture_processed.pickle')
with open('details.pickle','rb') as f:
    details = pickle.load(f)

# %%
review_df = pd.read_pickle('review_0213.csv')
review_df.dropna(axis=0,inplace=True)

# %%
lst=[]
for n,f in zip(review_df['name'],review_df['prof']):
    lst.append('-'.join([n,f]))

review_df['key'] = lst

review_df['senti'] = review_df['score'].apply(lambda x: int(x)>3)

lec_posi = review_df.groupby('key')['senti'].mean().reset_index()
prof_posi = review_df.groupby('prof')['senti'].mean().reset_index()

review_df['score'] = review_df['score'].apply(lambda x:int(x))

prof_score = review_df.groupby('prof')['score'].mean().reset_index()

# %%
prof_posi['senti2'] = 1 - prof_posi['senti']

# %%
prof_add = pd.merge(prof_posi,prof_score)

# %% [markdown]
# ## 데이터 합치기

# %%
# 유사도 모듈 결과값이랑 형식 통일
keys=[]
for i,k in zip(df_sum['과목명'],df_sum['교수명']) :
    keys.append('-'.join([str(i),str(k)]))

# %% [markdown]
# ### search_lecture 생성

# %%
df_sum['key'] = keys
df_export = pd.merge(df_sum,lec_sim,how='left')
df_export.loc[:,['sim','tags']] = df_export.loc[:,['sim','tags']].fillna('정보없음')

# %%
df_export.loc[df_export.query('교수명 ==""').index,'교수명']='None'

# %%
# detail 넣기 편하게 전처리 후 lecture 정보와 합치기
detail_to_export=[]
for i in details :
    n = i['name']
    p = i['prof']
    lst=[]
    for k in i['detail'].keys():
        lst.append(i['detail'][k])
    temp = {
        'name':n,
        'prof':p,
        '출석':lst[0],
        '성적비율':lst[1],
        '과제':lst[2],
        '팀플':lst[3],
        '시험횟수':lst[4]        
    }
    detail_to_export.append(temp)

df_details = pd.DataFrame.from_dict(detail_to_export)
df_details.replace('','정보없음',inplace=True)

temp=[]
for i,k in zip(df_details['name'],df_details['prof']):
    temp.append('-'.join([i,k]))
    
df_details['key']=temp
df_export = pd.merge(df_export,df_details, how = 'left')

# %%
# '[]' 형식 만들기 위한 함수
def process(x):
    if type(x) == str:
        return [x]
    else :
        return x

# %%
df_export['tags'] = df_export['tags'].apply(lambda x:process(x))

# %%
df_export = pd.merge(df_export,lec_posi,how='left')

df_export['senti2'] = 1-df_export['senti']

# %%
df_export.fillna(0,inplace=True)

# %%
df_export
# Out:
#                    과목명  교수명          과목분류       과목코드    평점  \
# 0               20세기패션  김수현        [전공선택]  071211-01     0
# 1               20세기패션  김의경        [전공선택]  071211-01     0
# 2               20세기패션  이은정        [전공선택]  071211-01     0
# 3      21세기창업과벤처(공학인증)  조봉환        [교양선택]  040396-01     0
# 4         21세기트렌드와정책이슈  김진동        [교양선택]  017163-91     0
# ...                ...  ...           ...        ...   ...
# 13478  휴먼테크놀로지캡스톤디자인II  이건상        [전공선택]  114840-01     0
# 13479  휴먼테크놀로지캡스톤디자인II  임시형        [전공선택]  114840-01     0
# 13480              희곡론  서재길        [전공선택]  000431-01  3.18
# 13481              희곡론  이화진        [전공선택]  000431-01     0
# 13482          희랍비극의이해  박규철  [교양선택, 자유교양]  040292-01     0
#
#                              소속코드  \
# 0                         의상디자인학과
# 1                         의상디자인학과
# 2                         의상디자인학과
# 3                     정치·경제·사회·세계
# 4                     정치·경제·사회·세계
# ...                           ...
# 13478              기계공학부 융합기계공학전공
# 13479  기계시스템공학부 융합기계공학전공(2017년폐지)
# 13480              한국어문학부 국어국문학전공
# 13481                      국어국문학과
# 13482                       역사·철학
#
#                                                       시간 학점  \
# 0      월 3(11:00-11:50) [조형관5층17호실],월 4(12:00-12:50) ...  2
# 1      화 5(13:00-13:50) [조형관5층15-1호실],화 6(14:00-14:50...  2
# 2      수 5(13:00-13:50) [조형관5층17호실]<br>수 6(14:00-14:5...  2
# 3      수 E(15:00-16:15) [경영관1층9호실],수 F(16:30-17:45) [...  3
# 4      토 0(08:00-08:50) [북악관6층9호실],토 1(09:00-09:50) [...  2
# ...                                                  ... ..
# 13478  금 6(14:00-14:50) [글로벌센터지하1층5호실]<br>금 7(15:00-1...  3
# 13479  화 6(14:00-14:50) [산학협력관지하1층3호실]<br>화 7(15:00-1...  3
# 13480  화 B(10:30-11:45) [북악관11층11호실]<br>목 B(10:30-11:...  3
# 13481  화 C(12:00-13:15) [북악관3층8호실]<br>화 D(13:30-14:45...  3
# 13482  금 5(13:00-13:50) [북악관3층10호실],금 6(14:00-14:50) ...  2
#
#                             비고                                         링크  \
# 0             타과생수강불가(다부전공자제외)   https://everytime.kr/lecture/view/859697
# 1              타과생수강불가(다전공자제외)   https://everytime.kr/lecture/view/547761
# 2             타과생수강불가(다부전공자제외)  https://everytime.kr/lecture/view/1418316
# 3                                https://everytime.kr/lecture/view/546056
# 4      행정관리학과(계약학과), 일반학생 수강불가   https://everytime.kr/lecture/view/542422
# ...                        ...                                        ...
# 13478                           https://everytime.kr/lecture/view/1417987
# 13479                           https://everytime.kr/lecture/view/2023123
# 13480                            https://everytime.kr/lecture/view/541677
# 13481                           https://everytime.kr/lecture/view/1081747
# 13482                            https://everytime.kr/lecture/view/546009
#
#        ...                  tags             name prof    출석    성적비율    과제  \
# 0      ...                [정보없음]           20세기패션  김수현  정보없음    정보없음  정보없음
# 1      ...                [정보없음]           20세기패션  김의경  정보없음    정보없음  정보없음
# 2      ...                [정보없음]           20세기패션  이은정  정보없음    정보없음  정보없음
# 3      ...                [정보없음]  21세기창업과벤처(공학인증)  조봉환  정보없음    정보없음  정보없음
# 4      ...                [정보없음]     21세기트렌드와정책이슈  김진동  정보없음    정보없음  정보없음
# ...    ...                   ...              ...  ...   ...     ...   ...
# 13478  ...                [정보없음]  휴먼테크놀로지캡스톤디자인II  이건상  정보없음    정보없음  정보없음
# 13479  ...                [정보없음]  휴먼테크놀로지캡스톤디자인II  임시형  정보없음    정보없음  정보없음
# 13480  ...  [연극, 쪽지, 발표, 퀴즈, 기준]              희곡론  서재길  직접호명  비율 채워줌    많음
# 13481  ...                [정보없음]              희곡론  이화진  정보없음    정보없음  정보없음
# 13482  ...                [정보없음]          희랍비극의이해  박규철  정보없음    정보없음  정보없음
#
#          팀플    시험횟수     senti    senti2
# 0      정보없음    정보없음  0.000000  0.000000
# 1      정보없음    정보없음  0.000000  0.000000
# 2      정보없음    정보없음  0.000000  0.000000
# 3      정보없음    정보없음  0.000000  0.000000
# 4      정보없음    정보없음  0.000000  0.000000
# ...     ...     ...       ...       ...
# 13478  정보없음    정보없음  0.000000  0.000000
# 13479  정보없음    정보없음  0.000000  0.000000
# 13480    보통  네 번 이상  0.454545  0.545455
# 13481  정보없음    정보없음  0.000000  0.000000
# 13482  정보없음    정보없음  0.000000  0.000000
#
# [13483 rows x 23 columns]

# %%
#search_lecture 모델생성
search_lecture=[]
for vals in df_export.values:
    temp = {
        "model" : "search.lecture",
        "fields" : {
            'name' : vals[0],
            'prof' : [vals[1]],
            'prof_name' : vals[1],
            'class_type' : str(vals[2]),
            'class_code' : vals[3],
            'score' : vals[4],
            'category' : vals[5],
            'icon' : [vals[5]],
            'time' : vals[6],
            'recommend_year' : vals[7],
            'remarks' : vals[8],
            'link' : vals[9],
            'semester' : str(vals[10]),
            'hash_tags' : str(vals[13]),
            
            'attendance' : str(vals[16]),
            'score_stlict' : str(vals[17]),
            'homework' : str(vals[18]),
            'teamplay' : str(vals[19]),
            'test_time': str(vals[20]),
            'positive' : vals[21],
            'negative' : vals[22]
        }
    }
    search_lecture.append(temp)

# %% [markdown]
# ### search_prof 생성

# %%
# 교수의 대표값(평균적인 강의 방식) 찾아주기
cols = ['성적비율','과제','팀플','시험횟수']
prof_details = df_details.query('출석 !="정보없음"')

# 최빈값 찾기 위해 list화
prof_details.iloc[:,2:7] = prof_details.iloc[:,2:7].applymap(lambda x:[x])
prof_mode = prof_details.groupby('prof')['출석'].sum().apply(lambda x:max(set(x), key=x.count)).reset_index()
# 최빈값으로 summary해서 저장
for i in cols:
    prof_mode = pd.merge(prof_mode,prof_details.groupby('prof')[i].sum().apply(lambda x:max(set(x), key=x.count)).reset_index(),how='right')
# Out:
# C:\Users\kcg99\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for_assign = df_export.copy()
for_assign['소속코드'] = for_assign['소속코드'].apply(process)

# %%
# 교수 소속 정보 얻기
prof_assign = for_assign.groupby('교수명')['소속코드'].sum().apply(lambda x:max(set(x), key=x.count)).reset_index() 
# 교수 정보들 합치기
prof_summary = pd.merge(prof_assign,prof_mode,how='left',left_on = '교수명', right_on ='prof')
# 결측치 대치
prof_summary.fillna('정보없음',inplace=True)

# %%
# 유사도와 합치기(tag 얻기 위함)
prof = pd.merge(prof_summary,prof_sim[['key','tags']],how='left',left_on='prof',right_on='key')
prof.drop('key',axis=1,inplace=True)
# 결측치 대치
prof['tags'] = prof['tags'].fillna('정보없음').apply(lambda x:process(x))

# %%
prof = pd.merge(prof,prof_add,how='left')

# %%
prof.columns
# Out:
# Index(['교수명', '소속코드', 'prof', '출석', '성적비율', '과제', '팀플', '시험횟수', 'tags',
#        'senti', 'senti2', 'score'],
#       dtype='object')

# %%
#search_prof 모델 생성
search_prof=[]
for i in prof.values:
    temp = {
        "model": "search.prof",
        "fields": {
            'name': i[0],
            'category' : i[1],
            'icon' : [i[1]],
            'hash_tags' : i[8],
            'attendance': i[3],
            'score_stlict': i[4],
            'homework' : i[5],
            'teamplay' : i[6],
            'test_time': i[7],
            'positive' : i[9],
            'negative' : i[10],
            'score' : i[11]
        }
        }
    search_prof.append(temp)

# %%
search_prof
# Out:
# [{'model': 'search.prof',
#   'fields': {'name': 'Andrew P. Ippoliti',
#    'category': '도자공예학과',
#    'icon': ['도자공예학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': 'Luo Tao',
#    'category': '시각디자인학과',
#    'icon': ['시각디자인학과'],
#    'hash_tags': ['선택', '폭탄', '유의', '디자인', '진로'],
#    'attendance': '반영안함',
#    'score_stlict': '비율 채워줌',
#    'homework': '많음',
#    'teamplay': '많음',
#    'test_time': '없음',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 5.0}},
#  {'model': 'search.prof',
#   'fields': {'name': 'None',
#    'category': '학과미배정',
#    'icon': ['학과미배정'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강경래',
#    'category': '언론정보학부 언론학전공',
#    'icon': ['언론정보학부 언론학전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강경모',
#    'category': '공연예술학부 무용전공',
#    'icon': ['공연예술학부 무용전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강경완',
#    'category': '국제학부 일본학전공',
#    'icon': ['국제학부 일본학전공'],
#    'hash_tags': ['일본어', '일본', '발표', '문화', '한자'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.5454545454545454,
#    'negative': 0.4545454545454546,
#    'score': 3.5090909090909093}},
#  {'model': 'search.prof',
#   'fields': {'name': '강경탁',
#    'category': '영상디자인학과',
#    'icon': ['영상디자인학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강구룡',
#    'category': '시각디자인학과',
#    'icon': ['시각디자인학과'],
#    'hash_tags': ['작업', '구체', '방향', '예시', '대로'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '없음',
#    'positive': 0.8,
#    'negative': 0.19999999999999996,
#    'score': 4.6}},
#  {'model': 'search.prof',
#   'fields': {'name': '강구용',
#    'category': '시각디자인학과',
#    'icon': ['시각디자인학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강규한',
#    'category': '영어영문학부 글로벌커뮤니케이션영어전공',
#    'icon': ['영어영문학부 글로벌커뮤니케이션영어전공'],
#    'hash_tags': ['에세이', '소설', '범위', '과제', '텍스트'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.5106382978723404,
#    'negative': 0.4893617021276596,
#    'score': 3.574468085106383}},
#  {'model': 'search.prof',
#   'fields': {'name': '강기우',
#    'category': '음악학부 성악전공',
#    'icon': ['음악학부 성악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강대오',
#    'category': '자동차IT융합학과',
#    'icon': ['자동차IT융합학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강동욱',
#    'category': '전자공학부 전자공학전공(2017년폐지)',
#    'icon': ['전자공학부 전자공학전공(2017년폐지)'],
#    'hash_tags': ['파이썬', '회로', '계산', '과제', '유튜브'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.8260869565217391,
#    'negative': 0.17391304347826086,
#    'score': 4.282608695652174}},
#  {'model': 'search.prof',
#   'fields': {'name': '강민규',
#    'category': '미술학부 입체미술전공',
#    'icon': ['미술학부 입체미술전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강민욱',
#    'category': '스포츠산업레저학과',
#    'icon': ['스포츠산업레저학과'],
#    'hash_tags': ['오픈', '생각', '객관식', '토론', '변별력'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 5.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강민재',
#    'category': '공연예술학부 연극전공',
#    'icon': ['공연예술학부 연극전공'],
#    'hash_tags': ['연극', '내내', '토의', '추천', '모임'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '보통',
#    'test_time': '한 번',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 5.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강병기',
#    'category': '정치·경제·사회·세계',
#    'icon': ['정치·경제·사회·세계'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강병석',
#    'category': '예·체능계',
#    'icon': ['예·체능계'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강병수',
#    'category': '시각디자인학과',
#    'icon': ['시각디자인학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강병태',
#    'category': '언론정보학부',
#    'icon': ['언론정보학부'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강병하',
#    'category': '기계시스템공학부 융합기계공학전공(2017년폐지)',
#    'icon': ['기계시스템공학부 융합기계공학전공(2017년폐지)'],
#    'hash_tags': ['사동', '팀', '평가', '독학', '성격'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '없음',
#    'positive': 0.39285714285714285,
#    'negative': 0.6071428571428572,
#    'score': 3.107142857142857}},
#  {'model': 'search.prof',
#   'fields': {'name': '강병환',
#    'category': '국제학부 중국학전공',
#    'icon': ['국제학부 중국학전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강보미',
#    'category': '문학·언어',
#    'icon': ['문학·언어'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강봉철',
#    'category': '기계공학부 에너지기계공학전공',
#    'icon': ['기계공학부 에너지기계공학전공'],
#    'hash_tags': ['코딩', '과제', '화요일', '피드백', '재능'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.8571428571428571,
#    'negative': 0.1428571428571429,
#    'score': 4.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강삼희',
#    'category': '법무학과',
#    'icon': ['법무학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강상호',
#    'category': '교양대학 교학팀',
#    'icon': ['교양대학 교학팀'],
#    'hash_tags': ['정치', '오픈', '논술', '이슈', '실제'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.46153846153846156,
#    'negative': 0.5384615384615384,
#    'score': 3.5384615384615383}},
#  {'model': 'search.prof',
#   'fields': {'name': '강서정',
#    'category': '교양대학 교학팀',
#    'icon': ['교양대학 교학팀'],
#    'hash_tags': ['내신', '고등학교', '영어', '발표', '친절'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '보통',
#    'test_time': '두 번',
#    'positive': 0.6436781609195402,
#    'negative': 0.3563218390804598,
#    'score': 3.5977011494252875}},
#  {'model': 'search.prof',
#   'fields': {'name': '강서희',
#    'category': '음악학부 성악전공',
#    'icon': ['음악학부 성악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강석민',
#    'category': '영상디자인학과',
#    'icon': ['영상디자인학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강석원',
#    'category': '기업경영학부 기업경영전공',
#    'icon': ['기업경영학부 기업경영전공'],
#    'hash_tags': ['말씀', '가량', '답안', '가산점', '당신'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 4.5}},
#  {'model': 'search.prof',
#   'fields': {'name': '강성식',
#    'category': '파이낸스보험경영학과',
#    'icon': ['파이낸스보험경영학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강소영',
#    'category': '공연예술학부 영화전공',
#    'icon': ['공연예술학부 영화전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강승민',
#    'category': '미술학부 입체미술전공',
#    'icon': ['미술학부 입체미술전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강승식',
#    'category': '컴퓨터공학부 컴퓨터공학전공',
#    'icon': ['컴퓨터공학부 컴퓨터공학전공'],
#    'hash_tags': ['언어', '과목', '과제', '자체', '설명'],
#    'attendance': '전자출결',
#    'score_stlict': '비율 채워줌',
#    'homework': '많음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.40816326530612246,
#    'negative': 0.5918367346938775,
#    'score': 3.0408163265306123}},
#  {'model': 'search.prof',
#   'fields': {'name': '강승희',
#    'category': '인성교육',
#    'icon': ['인성교육'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강신돈',
#    'category': '국제통상학과',
#    'icon': ['국제통상학과'],
#    'hash_tags': ['그래프', '이해', '설명', '프린트', '출석부'],
#    'attendance': '혼용',
#    'score_stlict': '학점느님',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.8529411764705882,
#    'negative': 0.1470588235294118,
#    'score': 4.235294117647059}},
#  {'model': 'search.prof',
#   'fields': {'name': '강신호',
#    'category': '교양대학 교학팀',
#    'icon': ['교양대학 교학팀'],
#    'hash_tags': ['취업', '인생', '창업', '도움', '고학년'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '없음',
#    'positive': 0.8571428571428571,
#    'negative': 0.1428571428571429,
#    'score': 4.428571428571429}},
#  {'model': 'search.prof',
#   'fields': {'name': '강아린',
#    'category': '컴퓨터공학부 컴퓨터공학전공',
#    'icon': ['컴퓨터공학부 컴퓨터공학전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '보통',
#    'teamplay': '많음',
#    'test_time': '세 번',
#    'positive': 0.0,
#    'negative': 1.0,
#    'score': 1.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강연미',
#    'category': '금속공예학과',
#    'icon': ['금속공예학과'],
#    'hash_tags': ['예술', '도망', '지각', '배점', '번복'],
#    'attendance': '직접호명',
#    'score_stlict': 'F 폭격기',
#    'homework': '많음',
#    'teamplay': '보통',
#    'test_time': '없음',
#    'positive': 0.0,
#    'negative': 1.0,
#    'score': 1.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강연식',
#    'category': '자동차IT융합학과',
#    'icon': ['자동차IT융합학과'],
#    'hash_tags': ['과제', '제어', '자동', '대회', '채점'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '한 번',
#    'positive': 0.7241379310344828,
#    'negative': 0.27586206896551724,
#    'score': 4.103448275862069}},
#  {'model': 'search.prof',
#   'fields': {'name': '강영세',
#    'category': '영어영문학과',
#    'icon': ['영어영문학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강영수',
#    'category': '기업경영학부 기업경영전공',
#    'icon': ['기업경영학부 기업경영전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강영신',
#    'category': '기업경영학부 기업경영전공',
#    'icon': ['기업경영학부 기업경영전공'],
#    'hash_tags': ['자격증', '엑셀', '중간고사', '파워', '포인트'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.7931034482758621,
#    'negative': 0.2068965517241379,
#    'score': 4.327586206896552}},
#  {'model': 'search.prof',
#   'fields': {'name': '강영심',
#    'category': '국사학과',
#    'icon': ['국사학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강영철',
#    'category': '행정정책학부 행정학전공',
#    'icon': ['행정정책학부 행정학전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강완모',
#    'category': '산림환경시스템학과',
#    'icon': ['산림환경시스템학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강우석',
#    'category': '과학·기술·자연(주)',
#    'icon': ['과학·기술·자연(주)'],
#    'hash_tags': ['개인', '힐링', '번호', '방향', '배경'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 4.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강우성',
#    'category': '음악학부 피아노전공',
#    'icon': ['음악학부 피아노전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강윤재',
#    'category': '사회학과',
#    'icon': ['사회학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강윤정',
#    'category': '경영학부',
#    'icon': ['경영학부'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강윤희',
#    'category': '국제학부 러시아학전공',
#    'icon': ['국제학부 러시아학전공'],
#    'hash_tags': ['역사', '지적', '영어', '세계사', '경제'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.45454545454545453,
#    'negative': 0.5454545454545454,
#    'score': 3.272727272727273}},
#  {'model': 'search.prof',
#   'fields': {'name': '강은경',
#    'category': '음악학부 관현악전공',
#    'icon': ['음악학부 관현악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강장석',
#    'category': '정치·경제·사회·세계',
#    'icon': ['정치·경제·사회·세계'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강재형',
#    'category': '경제학부 국제통상학전공(2010년폐지)',
#    'icon': ['경제학부 국제통상학전공(2010년폐지)'],
#    'hash_tags': ['객관식', '서술', '이해', '특이', '서술형'],
#    'attendance': '지정좌석',
#    'score_stlict': '비율 채워줌',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.55,
#    'negative': 0.44999999999999996,
#    'score': 3.6}},
#  {'model': 'search.prof',
#   'fields': {'name': '강정헌',
#    'category': '미술학부 회화전공',
#    'icon': ['미술학부 회화전공'],
#    'hash_tags': ['작품', '기준', '자유', '정확', '평가'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '없음',
#    'positive': 0.2,
#    'negative': 0.8,
#    'score': 2.3}},
#  {'model': 'search.prof',
#   'fields': {'name': '강정현',
#    'category': '금속공예학과',
#    'icon': ['금속공예학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강제신',
#    'category': '경영학부',
#    'icon': ['경영학부'],
#    'hash_tags': ['정보없음'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 4.5}},
#  {'model': 'search.prof',
#   'fields': {'name': '강주성',
#    'category': '수학과(2017년폐지)',
#    'icon': ['수학과(2017년폐지)'],
#    'hash_tags': ['과제', '취업', '패스', '진로', '출석'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.6415094339622641,
#    'negative': 0.3584905660377359,
#    'score': 3.8773584905660377}},
#  {'model': 'search.prof',
#   'fields': {'name': '강지영',
#    'category': '음악학부 작곡전공',
#    'icon': ['음악학부 작곡전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강지웅',
#    'category': '미술학부 회화전공',
#    'icon': ['미술학부 회화전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강지훈',
#    'category': '나노전자물리학과',
#    'icon': ['나노전자물리학과'],
#    'hash_tags': ['꼰대', '영상', '과학', '과제', '공대'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.4230769230769231,
#    'negative': 0.5769230769230769,
#    'score': 2.8461538461538463}},
#  {'model': 'search.prof',
#   'fields': {'name': '강태구',
#    'category': '컴퓨터공학부 컴퓨터공학전공',
#    'icon': ['컴퓨터공학부 컴퓨터공학전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강태권',
#    'category': '중국학부 중국어문전공',
#    'icon': ['중국학부 중국어문전공'],
#    'hash_tags': ['발표', '번역', '등록금', '단어', '선사'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '한 번',
#    'positive': 0.41379310344827586,
#    'negative': 0.5862068965517242,
#    'score': 2.9655172413793105}},
#  {'model': 'search.prof',
#   'fields': {'name': '강태월',
#    'category': '중어중문학과',
#    'icon': ['중어중문학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강태현',
#    'category': '응용화학부 바이오의약전공',
#    'icon': ['응용화학부 바이오의약전공'],
#    'hash_tags': ['생명', '객관식', '경악', '뭔가', '휴대폰'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 4.8}},
#  {'model': 'search.prof',
#   'fields': {'name': '강필수',
#    'category': '음악학부 성악전공',
#    'icon': ['음악학부 성악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강한태',
#    'category': '자동차ㆍ운송디자인학과',
#    'icon': ['자동차ㆍ운송디자인학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강향숙',
#    'category': '음악학부 작곡전공',
#    'icon': ['음악학부 작곡전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강현경',
#    'category': '교양대학 교학팀',
#    'icon': ['교양대학 교학팀'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강현모',
#    'category': '경영학부 경영학전공',
#    'icon': ['경영학부 경영학전공'],
#    'hash_tags': ['팀', '사례', '경영', '마케팅', '진심'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.8055555555555556,
#    'negative': 0.19444444444444442,
#    'score': 4.166666666666667}},
#  {'model': 'search.prof',
#   'fields': {'name': '강현선',
#    'category': '미술학부 입체미술전공',
#    'icon': ['미술학부 입체미술전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강현주',
#    'category': '기업융합법학과',
#    'icon': ['기업융합법학과'],
#    'hash_tags': ['플러스', '제로', '인품', '나감', '출석'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.375,
#    'negative': 0.625,
#    'score': 3.125}},
#  {'model': 'search.prof',
#   'fields': {'name': '강혜리',
#    'category': '음악학부 관현악전공',
#    'icon': ['음악학부 관현악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강혜명',
#    'category': '음악학부 성악전공',
#    'icon': ['음악학부 성악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강혜영',
#    'category': '음악학부 피아노전공',
#    'icon': ['음악학부 피아노전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강화선',
#    'category': '시각디자인학과',
#    'icon': ['시각디자인학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강효선',
#    'category': '경영학부 경영학전공',
#    'icon': ['경영학부 경영학전공'],
#    'hash_tags': ['보험', '사례', '기초', '지식', '서술형'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.8571428571428571,
#    'negative': 0.1428571428571429,
#    'score': 4.571428571428571}},
#  {'model': 'search.prof',
#   'fields': {'name': '강효지',
#    'category': '음악학부 피아노전공',
#    'icon': ['음악학부 피아노전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '강희정',
#    'category': '금속공예학과',
#    'icon': ['금속공예학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '갤러거',
#    'category': '학과미배정',
#    'icon': ['학과미배정'],
#    'hash_tags': ['대화', '분반', '과제', '에이', '자신'],
#    'attendance': '혼용',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 4.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '경미수',
#    'category': '음악학부 작곡전공',
#    'icon': ['음악학부 작곡전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '경민기',
#    'category': '경영정보학부',
#    'icon': ['경영정보학부'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '경종인',
#    'category': '임산생명공학과',
#    'icon': ['임산생명공학과'],
#    'hash_tags': ['문과', '필기', '내용', '강조', '이과'],
#    'attendance': '혼용',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.8297872340425532,
#    'negative': 0.17021276595744683,
#    'score': 4.425531914893617}},
#  {'model': 'search.prof',
#   'fields': {'name': '계봉오',
#    'category': '사회학과',
#    'icon': ['사회학과'],
#    'hash_tags': ['사회학', '내용', '그래프', '범위', '교양'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.4722222222222222,
#    'negative': 0.5277777777777778,
#    'score': 3.611111111111111}},
#  {'model': 'search.prof',
#   'fields': {'name': '고광웅',
#    'category': '식품영양학과',
#    'icon': ['식품영양학과'],
#    'hash_tags': ['과학', '퀴즈', '이상', '시간', '처리'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '네 번 이상',
#    'positive': 0.375,
#    'negative': 0.625,
#    'score': 3.125}},
#  {'model': 'search.prof',
#   'fields': {'name': '고광진',
#    'category': '기업경영학부 기업경영전공',
#    'icon': ['기업경영학부 기업경영전공'],
#    'hash_tags': ['친절', '반복', '설명', '부분', '회계'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 4.96969696969697}},
#  {'model': 'search.prof',
#   'fields': {'name': '고기영',
#    'category': '교양대학 교학팀',
#    'icon': ['교양대학 교학팀'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고댕',
#    'category': '정치외교학과',
#    'icon': ['정치외교학과'],
#    'hash_tags': ['영어', '에세이', '필기', '발음', '점수'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.7948717948717948,
#    'negative': 0.20512820512820518,
#    'score': 4.243589743589744}},
#  {'model': 'search.prof',
#   'fields': {'name': '고동연',
#    'category': '미술학부 입체미술전공',
#    'icon': ['미술학부 입체미술전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고동욱',
#    'category': '산림환경시스템학과',
#    'icon': ['산림환경시스템학과'],
#    'hash_tags': ['토론', '내용', '출결', '북한', '놀람'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '없음',
#    'positive': 0.6,
#    'negative': 0.4,
#    'score': 3.72}},
#  {'model': 'search.prof',
#   'fields': {'name': '고동현',
#    'category': '사회학과',
#    'icon': ['사회학과'],
#    'hash_tags': ['한숨', '열의', '필수', '정도', '힐링'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '없음',
#    'positive': 0.0,
#    'negative': 1.0,
#    'score': 3.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고마음',
#    'category': '음악학부 피아노전공',
#    'icon': ['음악학부 피아노전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고맴',
#    'category': 'KMU International School Information Technology',
#    'icon': ['KMU International School Information Technology'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고민정',
#    'category': '식품영양학과',
#    'icon': ['식품영양학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고범진',
#    'category': '실내디자인학과',
#    'icon': ['실내디자인학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고병성',
#    'category': '미술학부 입체미술전공',
#    'icon': ['미술학부 입체미술전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고석현',
#    'category': '과학·기술·자연',
#    'icon': ['과학·기술·자연'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고성란',
#    'category': '교양대학 교학팀',
#    'icon': ['교양대학 교학팀'],
#    'hash_tags': ['활동', '조별', '내신', '팀', '고등학교'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '많음',
#    'test_time': '두 번',
#    'positive': 0.8478260869565217,
#    'negative': 0.15217391304347827,
#    'score': 4.206521739130435}},
#  {'model': 'search.prof',
#   'fields': {'name': '고성일',
#    'category': '행정관리학과',
#    'icon': ['행정관리학과'],
#    'hash_tags': ['공연', '감상문', '정리', '연극', '노트'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '한 번',
#    'positive': 0.6222222222222222,
#    'negative': 0.37777777777777777,
#    'score': 3.8222222222222224}},
#  {'model': 'search.prof',
#   'fields': {'name': '고성호',
#    'category': '음악학부 성악전공',
#    'icon': ['음악학부 성악전공'],
#    'hash_tags': ['노래', '모임', '시간', '팀', '음악'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '많음',
#    'test_time': '두 번',
#    'positive': 0.5,
#    'negative': 0.5,
#    'score': 3.1538461538461537}},
#  {'model': 'search.prof',
#   'fields': {'name': '고수석',
#    'category': '교육학과(2017년폐지)',
#    'icon': ['교육학과(2017년폐지)'],
#    'hash_tags': ['통일', '토론', '매체', '시청각', '전문가'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.5,
#    'negative': 0.5,
#    'score': 4.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고연수',
#    'category': '도자공예학과',
#    'icon': ['도자공예학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고영희',
#    'category': '자동차공학과',
#    'icon': ['자동차공학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고용규',
#    'category': '과학·기술·자연(주)',
#    'icon': ['과학·기술·자연(주)'],
#    'hash_tags': ['주세요', '비플', '개꿀', '양식', '엑셀'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.9375,
#    'negative': 0.0625,
#    'score': 4.5625}},
#  {'model': 'search.prof',
#   'fields': {'name': '고욱',
#    'category': '금속공예학과',
#    'icon': ['금속공예학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고원상',
#    'category': '영상디자인학과',
#    'icon': ['영상디자인학과'],
#    'hash_tags': ['그림', '그쪽', '크리', '과제', '다음'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '많음',
#    'teamplay': '없음',
#    'test_time': '없음',
#    'positive': 0.0,
#    'negative': 1.0,
#    'score': 2.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고은미',
#    'category': '음악학부 작곡전공',
#    'icon': ['음악학부 작곡전공'],
#    'hash_tags': ['동시', '세상', '순간', '진행', '방향'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '한 번',
#    'positive': 0.0,
#    'negative': 1.0,
#    'score': 1.25}},
#  {'model': 'search.prof',
#   'fields': {'name': '고은주',
#    'category': '공간디자인학과',
#    'icon': ['공간디자인학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고익현',
#    'category': '정치·경제·사회·세계',
#    'icon': ['정치·경제·사회·세계'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고재백',
#    'category': '한국역사학과',
#    'icon': ['한국역사학과'],
#    'hash_tags': ['역사', '영화', '세계사', '내용', '주제'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.8064516129032258,
#    'negative': 0.19354838709677424,
#    'score': 4.290322580645161}},
#  {'model': 'search.prof',
#   'fields': {'name': '고정석',
#    'category': '건축학부 건축학전공',
#    'icon': ['건축학부 건축학전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고정오',
#    'category': '기업경영학부',
#    'icon': ['기업경영학부'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고지연',
#    'category': '학과미배정',
#    'icon': ['학과미배정'],
#    'hash_tags': ['여러분', '실화', '해석', '시간', '작품'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '보통',
#    'test_time': '두 번',
#    'positive': 0.3076923076923077,
#    'negative': 0.6923076923076923,
#    'score': 2.3846153846153846}},
#  {'model': 'search.prof',
#   'fields': {'name': '고태준',
#    'category': '나노전자물리학과',
#    'icon': ['나노전자물리학과'],
#    'hash_tags': ['실험', '물리', '발표', '조교', '물리학'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.8787878787878788,
#    'negative': 0.12121212121212122,
#    'score': 4.363636363636363}},
#  {'model': 'search.prof',
#   'fields': {'name': '고한준',
#    'category': '언론정보학부 광고학전공',
#    'icon': ['언론정보학부 광고학전공'],
#    'hash_tags': ['광고', '최고', '참여', '점수', '자퇴'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.813953488372093,
#    'negative': 0.18604651162790697,
#    'score': 4.441860465116279}},
#  {'model': 'search.prof',
#   'fields': {'name': '고해종',
#    'category': '예·체능계(주)',
#    'icon': ['예·체능계(주)'],
#    'hash_tags': ['연극', '출석', '포기', '얼굴', '등장'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '보통',
#    'test_time': '두 번',
#    'positive': 0.25,
#    'negative': 0.75,
#    'score': 1.75}},
#  {'model': 'search.prof',
#   'fields': {'name': '고현숙',
#    'category': '경영학부 경영학전공',
#    'icon': ['경영학부 경영학전공'],
#    'hash_tags': ['차지', '이것저것', '팀', '다양', '발표'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '없음',
#    'teamplay': '보통',
#    'test_time': '두 번',
#    'positive': 0.6842105263157895,
#    'negative': 0.3157894736842105,
#    'score': 4.105263157894737}},
#  {'model': 'search.prof',
#   'fields': {'name': '고현아',
#    'category': '음악학부 성악전공',
#    'icon': ['음악학부 성악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고현혜',
#    'category': '자동차공학과',
#    'icon': ['자동차공학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '고희탁',
#    'category': '정치외교학과',
#    'icon': ['정치외교학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '곡효여',
#    'category': '국제학부 중국학전공(2017년폐지)',
#    'icon': ['국제학부 중국학전공(2017년폐지)'],
#    'hash_tags': ['중국어', '발음', '편애', '단어', '기초'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.7586206896551724,
#    'negative': 0.24137931034482762,
#    'score': 4.241379310344827}},
#  {'model': 'search.prof',
#   'fields': {'name': '공강일',
#    'category': '공업디자인학과',
#    'icon': ['공업디자인학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '공선희',
#    'category': '사회학과',
#    'icon': ['사회학과'],
#    'hash_tags': ['종이', '의견', '졸음', '사회학', '주제'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '보통',
#    'teamplay': '많음',
#    'test_time': '두 번',
#    'positive': 0.0,
#    'negative': 1.0,
#    'score': 1.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '공세진',
#    'category': '체육학부 경기지도학전공(2013년폐지)',
#    'icon': ['체육학부 경기지도학전공(2013년폐지)'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '공승현',
#    'category': '자동차ㆍ운송디자인학과',
#    'icon': ['자동차ㆍ운송디자인학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '공연화',
#    'category': '공연예술학부 무용전공',
#    'icon': ['공연예술학부 무용전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '공옥례',
#    'category': '기업경영학부 기업경영전공',
#    'icon': ['기업경영학부 기업경영전공'],
#    'hash_tags': ['사례', '토론', '마니', '의견', '피티'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '없음',
#    'teamplay': '보통',
#    'test_time': '두 번',
#    'positive': 0.0,
#    'negative': 1.0,
#    'score': 2.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '공유식',
#    'category': '국제학부 중국학전공',
#    'icon': ['국제학부 중국학전공'],
#    'hash_tags': ['공휴일', '리뷰', '중국', '문화', '부분'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '한 번',
#    'positive': 0.5,
#    'negative': 0.5,
#    'score': 3.5}},
#  {'model': 'search.prof',
#   'fields': {'name': '공진동',
#    'category': 'KMU International School Information Technology',
#    'icon': ['KMU International School Information Technology'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '곽기영',
#    'category': '경영정보학부 비즈니스IT전공',
#    'icon': ['경영정보학부 비즈니스IT전공'],
#    'hash_tags': ['연습', '팀', '핸드폰', '사용', '코딩'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.5833333333333334,
#    'negative': 0.41666666666666663,
#    'score': 3.5416666666666665}},
#  {'model': 'search.prof',
#   'fields': {'name': '곽선희',
#    'category': '인성교육',
#    'icon': ['인성교육'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '곽신웅',
#    'category': '기계공학부 에너지기계공학전공',
#    'icon': ['기계공학부 에너지기계공학전공'],
#    'hash_tags': ['수치', '과제', '목소리', '해석', '점수'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '많음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.5185185185185185,
#    'negative': 0.4814814814814815,
#    'score': 3.3703703703703702}},
#  {'model': 'search.prof',
#   'fields': {'name': '곽영우',
#    'category': '도자공예학과',
#    'icon': ['도자공예학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '곽은심',
#    'category': '국제학부 일본학전공',
#    'icon': ['국제학부 일본학전공'],
#    'hash_tags': ['친절', '실수', '하나', '점수', '내용'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 4.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '곽인상',
#    'category': '공연예술학부 무용전공',
#    'icon': ['공연예술학부 무용전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '곽지영',
#    'category': '언론정보학부 광고학전공',
#    'icon': ['언론정보학부 광고학전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '곽창규',
#    'category': '경제학과',
#    'icon': ['경제학과'],
#    'hash_tags': ['복수', '전공', '힐링', '번역', '방해'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.0,
#    'negative': 1.0,
#    'score': 1.75}},
#  {'model': 'search.prof',
#   'fields': {'name': '곽철종',
#    'category': '미술학부 회화전공',
#    'icon': ['미술학부 회화전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '곽현주',
#    'category': '음악학부 성악전공',
#    'icon': ['음악학부 성악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '곽효일',
#    'category': '음악학부 관현악전공',
#    'icon': ['음악학부 관현악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '구경서',
#    'category': '교양대학 교학팀',
#    'icon': ['교양대학 교학팀'],
#    'hash_tags': ['정치', '용어', '원탑', '과제', '정리'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.6,
#    'negative': 0.4,
#    'score': 3.8}},
#  {'model': 'search.prof',
#   'fields': {'name': '구근회',
#    'category': '공연예술학부 연극전공',
#    'icon': ['공연예술학부 연극전공'],
#    'hash_tags': ['팀', '과제', '힐링', '번역기', '방향'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '많음',
#    'teamplay': '많음',
#    'test_time': '없음',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 4.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '구기수',
#    'category': '미술학부 입체미술전공',
#    'icon': ['미술학부 입체미술전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '구두회',
#    'category': '예·체능계',
#    'icon': ['예·체능계'],
# ...
#    'teamplay': '없음',
#    'test_time': '없음',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 5.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박미령',
#    'category': '과학·기술·자연',
#    'icon': ['과학·기술·자연'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박미애',
#    'category': '소프트웨어학부 소프트웨어전공',
#    'icon': ['소프트웨어학부 소프트웨어전공'],
#    'hash_tags': ['수학', '설명', '증명', '고등학교', '과제'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '많음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.8082191780821918,
#    'negative': 0.1917808219178082,
#    'score': 4.1506849315068495}},
#  {'model': 'search.prof',
#   'fields': {'name': '박미연',
#    'category': '금속공예학과',
#    'icon': ['금속공예학과'],
#    'hash_tags': ['전시', '방문', '미술', '현대', '제도'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '보통',
#    'test_time': '두 번',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 4.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박미예',
#    'category': '건축학부 건축학전공(2013년폐지)',
#    'icon': ['건축학부 건축학전공(2013년폐지)'],
#    'hash_tags': ['크리', '재료', '건축', '발표', '설계'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '없음',
#    'positive': 0.4375,
#    'negative': 0.5625,
#    'score': 3.6875}},
#  {'model': 'search.prof',
#   'fields': {'name': '박민',
#    'category': '법학부 공법학전공',
#    'icon': ['법학부 공법학전공'],
#    'hash_tags': ['판례', '객관식', '발표', '복습', '피피티'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.8818181818181818,
#    'negative': 0.11818181818181817,
#    'score': 4.663636363636364}},
#  {'model': 'search.prof',
#   'fields': {'name': '박민근',
#    'category': '컴퓨터공학부',
#    'icon': ['컴퓨터공학부'],
#    'hash_tags': ['게임', '현업', '프로젝트', '소스', '생각'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '많음',
#    'test_time': '두 번',
#    'positive': 0.6136363636363636,
#    'negative': 0.38636363636363635,
#    'score': 3.6818181818181817}},
#  {'model': 'search.prof',
#   'fields': {'name': '박민준',
#    'category': '영상디자인학과',
#    'icon': ['영상디자인학과'],
#    'hash_tags': ['내년', '힐링', '번역기', '방향', '배경'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '많음',
#    'teamplay': '없음',
#    'test_time': '한 번',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 5.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박민희',
#    'category': '미술학부 회화전공',
#    'icon': ['미술학부 회화전공'],
#    'hash_tags': ['작업', '칭찬', '마인드', '한국', '이해'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '많음',
#    'teamplay': '없음',
#    'test_time': '없음',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 4.5}},
#  {'model': 'search.prof',
#   'fields': {'name': '박범서',
#    'category': '학과미배정',
#    'icon': ['학과미배정'],
#    'hash_tags': ['프로젝트', '이것', '팀', '방향', '배경'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '많음',
#    'test_time': '없음',
#    'positive': 0.0,
#    'negative': 1.0,
#    'score': 3.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박병준',
#    'category': '경영학부 경영학전공',
#    'icon': ['경영학부 경영학전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박보름',
#    'category': '영상디자인학과',
#    'icon': ['영상디자인학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박봉순',
#    'category': '교양대학 교학팀',
#    'icon': ['교양대학 교학팀'],
#    'hash_tags': ['중국어', '한자', '본문', '짝꿍', '대화'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.5208333333333334,
#    'negative': 0.47916666666666663,
#    'score': 3.3125}},
#  {'model': 'search.prof',
#   'fields': {'name': '박상미',
#    'category': '음악학부 관현악전공',
#    'icon': ['음악학부 관현악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박상수',
#    'category': '기계시스템공학부',
#    'icon': ['기계시스템공학부'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박상숙',
#    'category': '미술학부 회화전공',
#    'icon': ['미술학부 회화전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박상영',
#    'category': '음악학부 성악전공',
#    'icon': ['음악학부 성악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박상욱',
#    'category': '건축학부 건축학전공(2013년폐지)',
#    'icon': ['건축학부 건축학전공(2013년폐지)'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박상준',
#    'category': '경영정보학부 비즈니스IT전공(2013년폐지)',
#    'icon': ['경영정보학부 비즈니스IT전공(2013년폐지)'],
#    'hash_tags': ['마케팅', '생각', '주관', '철학', '발표'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.43373493975903615,
#    'negative': 0.5662650602409638,
#    'score': 3.180722891566265}},
#  {'model': 'search.prof',
#   'fields': {'name': '박서연',
#    'category': '공연예술학부 영화전공',
#    'icon': ['공연예술학부 영화전공'],
#    'hash_tags': ['영화', '편향', '전후', '다큐', '감상'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '한 번',
#    'positive': 0.4,
#    'negative': 0.6,
#    'score': 3.6}},
#  {'model': 'search.prof',
#   'fields': {'name': '박석진',
#    'category': '교양대학 교학팀',
#    'icon': ['교양대학 교학팀'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박선경',
#    'category': '의상디자인학과',
#    'icon': ['의상디자인학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박선영',
#    'category': '국제학부 일본학전공(2017년폐지)',
#    'icon': ['국제학부 일본학전공(2017년폐지)'],
#    'hash_tags': ['일본', '과제', '논문', '일본어', '영화'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '한 번',
#    'positive': 0.6363636363636364,
#    'negative': 0.36363636363636365,
#    'score': 3.727272727272727}},
#  {'model': 'search.prof',
#   'fields': {'name': '박선환',
#    'category': '교직',
#    'icon': ['교직'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박성건',
#    'category': '체육학부 스포츠건강재활전공',
#    'icon': ['체육학부 스포츠건강재활전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박성열',
#    'category': '기업경영학부 기업경영전공',
#    'icon': ['기업경영학부 기업경영전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박성욱',
#    'category': '도자공예학과',
#    'icon': ['도자공예학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박성은',
#    'category': '인성교육',
#    'icon': ['인성교육'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박성주',
#    'category': '체육학부 스포츠지도전공',
#    'icon': ['체육학부 스포츠지도전공'],
#    'hash_tags': ['토론', '윤리', '스포츠', '놀람', '평가'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '없음',
#    'teamplay': '보통',
#    'test_time': '없음',
#    'positive': 1.0,
#    'negative': 0.0,
#    'score': 5.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박성준',
#    'category': '경영학부 경영학전공',
#    'icon': ['경영학부 경영학전공'],
#    'hash_tags': ['문제지', '기준', '평가', '팀', '강조'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '없음',
#    'teamplay': '보통',
#    'test_time': '두 번',
#    'positive': 0.6666666666666666,
#    'negative': 0.33333333333333337,
#    'score': 4.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박성태',
#    'category': '신소재공학부 신소재공학전공',
#    'icon': ['신소재공학부 신소재공학전공'],
#    'hash_tags': ['번복', '반도체', '기도', '최악', '오타'],
#    'attendance': '전자출결',
#    'score_stlict': '비율 채워줌',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.0,
#    'negative': 1.0,
#    'score': 1.3333333333333333}},
#  {'model': 'search.prof',
#   'fields': {'name': '박성현',
#    'category': '건축학부 건축학전공(2013년폐지)',
#    'icon': ['건축학부 건축학전공(2013년폐지)'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박성형',
#    'category': '건축학부 건축학전공',
#    'icon': ['건축학부 건축학전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박성혜',
#    'category': '전자공학부',
#    'icon': ['전자공학부'],
#    'hash_tags': ['물리', '실험', '보고서', '설명', '퀴즈'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.8317757009345794,
#    'negative': 0.16822429906542058,
#    'score': 4.383177570093458}},
#  {'model': 'search.prof',
#   'fields': {'name': '박성호',
#    'category': '컴퓨터공학부',
#    'icon': ['컴퓨터공학부'],
#    'hash_tags': ['사담', '기사', '견학', '피드백', '시간'],
#    'attendance': '직접호명',
#    'score_stlict': 'F 폭격기',
#    'homework': '없음',
#    'teamplay': '없음',
#    'test_time': '없음',
#    'positive': 0.375,
#    'negative': 0.625,
#    'score': 2.9375}},
#  {'model': 'search.prof',
#   'fields': {'name': '박성희',
#    'category': '경영학부 경영학전공',
#    'icon': ['경영학부 경영학전공'],
#    'hash_tags': ['파워', '외국인', '포인트', '엑셀', '채점'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '많음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.5,
#    'negative': 0.5,
#    'score': 3.3333333333333335}},
#  {'model': 'search.prof',
#   'fields': {'name': '박세진',
#    'category': '음악학부 작곡전공',
#    'icon': ['음악학부 작곡전공'],
#    'hash_tags': ['음악', '감상문', '팀', '시청각', '장르'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '보통',
#    'test_time': '한 번',
#    'positive': 0.75,
#    'negative': 0.25,
#    'score': 3.75}},
#  {'model': 'search.prof',
#   'fields': {'name': '박세희',
#    'category': '미술학부',
#    'icon': ['미술학부'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박소언',
#    'category': 'KMU International School Information Technology',
#    'icon': ['KMU International School Information Technology'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박소영',
#    'category': '정치·경제·사회·세계(주)',
#    'icon': ['정치·경제·사회·세계(주)'],
#    'hash_tags': ['상위', '감상문', '인원', '재미', '대체'],
#    'attendance': '직접호명',
#    'score_stlict': '학점느님',
#    'homework': '보통',
#    'teamplay': '없음',
#    'test_time': '한 번',
#    'positive': 0.3333333333333333,
#    'negative': 0.6666666666666667,
#    'score': 3.3333333333333335}},
#  {'model': 'search.prof',
#   'fields': {'name': '박소헌',
#    'category': '음악학부 성악전공',
#    'icon': ['음악학부 성악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박소현',
#    'category': '언론정보학부 광고홍보학전공',
#    'icon': ['언론정보학부 광고홍보학전공'],
#    'hash_tags': ['비중', '홍보', '참여', '광고', '팀'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '보통',
#    'teamplay': '보통',
#    'test_time': '한 번',
#    'positive': 0.5,
#    'negative': 0.5,
#    'score': 4.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박수연',
#    'category': '금속공예학과',
#    'icon': ['금속공예학과'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박수인',
#    'category': '정치외교학과',
#    'icon': ['정치외교학과'],
#    'hash_tags': ['국가', '생각', '발표', '시간', '자신'],
#    'attendance': '직접호명',
#    'score_stlict': '매우 깐깐함',
#    'homework': '없음',
#    'teamplay': '보통',
#    'test_time': '두 번',
#    'positive': 0.625,
#    'negative': 0.375,
#    'score': 3.375}},
#  {'model': 'search.prof',
#   'fields': {'name': '박수진',
#    'category': '음악학부 관현악전공',
#    'icon': ['음악학부 관현악전공'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박수현',
#    'category': '경영정보학부 정보시스템전공',
#    'icon': ['경영정보학부 정보시스템전공'],
#    'hash_tags': ['파이썬', '라이브', '코딩', '과제', '진도'],
#    'attendance': '직접호명',
#    'score_stlict': '비율 채워줌',
#    'homework': '많음',
#    'teamplay': '없음',
#    'test_time': '두 번',
#    'positive': 0.49056603773584906,
#    'negative': 0.5094339622641509,
#    'score': 3.30188679245283}},
#  {'model': 'search.prof',
#   'fields': {'name': '박수호',
#    'category': '인성교육',
#    'icon': ['인성교육'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  {'model': 'search.prof',
#   'fields': {'name': '박숙영',
#    'category': '교양대학 교학팀',
#    'icon': ['교양대학 교학팀'],
#    'hash_tags': ['정보없음'],
#    'attendance': '정보없음',
#    'score_stlict': '정보없음',
#    'homework': '정보없음',
#    'teamplay': '정보없음',
#    'test_time': '정보없음',
#    'positive': 0.0,
#    'negative': 0.0,
#    'score': 0.0}},
#  ...]

# %% [markdown]
# ## search_similarlecture 모델 생성

# %%
# search_similarlecture 모델 생성
pk = 1
search_similarlecture=[]
for ks,ss in zip(lec_sim['key'],lec_sim['sim']):
    k = ks.split('-')
    
    if len(k) <= 2 :
        temp_name = k[0]
        temp_prof = k[1]
        
    elif len(k) > 2 :
        temp_name = ('-'.join(k[:-1]))
        temp_prof = (k[-1])
        
    for sr in ss:
        s = sr.split('-')
        if len(s) <= 2 :
            temp_name_sim = s[0]
            temp_prof_sim = s[1]
        
        elif len(s) > 2 :
            temp_name_sim = ('-'.join(s[:-1]))
            temp_prof_sim = (s[-1])
        
        temp={
            "model": "search.similarlecture",
            "pk": pk,
            "fields": {
            "similar_from": [
                temp_name,
                temp_prof
            ],
            "similar_to": [
                temp_name_sim,
                temp_prof_sim
            ]
            }
            }
        search_similarlecture.append(temp)
        pk += 1

# %% [markdown]
# ## search_similarprof 모델 생성

# %%
# search_similarprof 모델 생성
search_similarprof=[]
pk = 1
for k,ss in zip(prof_sim['key'],prof_sim['sim']):
    for s in ss:
        temp={
          "model": "search.similarprof",
          "pk": pk,
          "fields": {
            "similar_from": [
              k
            ],
            "similar_to": [
              s
            ]
          }
        }
        search_similarprof.append(temp)
        pk += 1

# %%
with open('search_lecture.json', 'w', encoding = 'utf-8') as f:
    json.dump(search_lecture, f , ensure_ascii=False)

# %%
with open('search_prof.json', 'w', encoding = 'utf-8') as f:
    json.dump(search_prof, f , ensure_ascii=False)

# %%
with open('search_similarlecture.json', 'w', encoding = 'utf-8') as f:
    json.dump(search_similarlecture, f , ensure_ascii=False)

# %%
with open('search_similarprof.json', 'w', encoding = 'utf-8') as f:
    json.dump(search_similarprof, f , ensure_ascii=False)
